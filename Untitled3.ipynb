# %%
# %pylab inline
import scipy.linalg as alg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/Users/aloukian/Documents/fdm')
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %%
import fdm

# %%
#plot(real(fdm.make_lorenzian(1000, [2, 5, 10], [4 - 1j, 8 - 2j, 7 - 0.1j], dt=0.1)))

# %%
import itertools as it
amps = [10, 5, 10]
freqs = [4 - 1j, 8 - 2j, 7 - 0.100j]
df = linspace(-10, 0, 500)

analytic = zeros_like(df, dtype=complex128)
for a, f in it.izip(amps, freqs):
    analytic += a*1./(imag(-f) + 1j*(df - real(-f)))
plot(real(analytic))
a = real(analytic)

one = real(amps[0]*1./(imag(-freqs[0]) + 1j*(df - real(-freqs[0]))))
two = real(amps[1]*1./(imag(-freqs[1]) + 1j*(df - real(-freqs[1]))))
three = real(amps[2]*1./(imag(-freqs[2]) + 1j*(df - real(-freqs[2]))))

# %%
plot(one)
plot(two)
plot(three)

# %%
u, s, v = svd(vstack([one, two, three]))

# %%
plot(v[0, :])
plot(v[1, :])
plot(v[2, :])

# %%
a1 = np.dot(v[0, :], one)
a2 = np.dot(v[1, :], one)
a3 = np.dot(v[2, :], one)
plot(a1*v[0, :] + a2*v[1, :] + a3 * v[2, :])

# %%
b1 = np.dot(v[0, :], two)
b2 = np.dot(v[1, :], two)
b3 = np.dot(v[2, :], two)
plot(b1*v[0, :] + b2*v[1, :] + b3 * v[2, :])

# %%
plot(
