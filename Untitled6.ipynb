# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (16, 12)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import nudie

# %%
df = nudie.SpeFile(r'Z:\2D\Data\14-10-07\DO\Probe_LO_Separation_Cent_750nm.spe')
df.readout_time
# Out:
# 1.8990000486373901

# %%
data = squeeze(df.data)

# %%
plot(data)

# %%
wl = nudie.simple_wavelength_axis(600, center_wavelength=750)
plot(wl, data)

# %%
freq, dataf, df = nudie.wavelen_to_freq(wl, data, ret_df=True)

# %%
plot(freq, data)

# %%
fft_f = fftfreq(freq.shape[0], df)
data_f = abs(fft.fft(dataf))

# %%
plot(fft_f, data_f)
xlim(10, 5000)
# Out:
# (10, 5000)

# %%
import pint
q = pint.UnitRegistry()

# %%
((900*q.fs)*q.speed_of_light/1.55).to('mm')
# Out:
# <Quantity(0.17407304012903227, 'millimeter')>
