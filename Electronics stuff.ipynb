# %%
import numpy as np

# %%
import quantities as qt

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (12, 12)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
R1 = 3000
R2 = 10000

k = linspace(1, 0, 1000)

val = (1 - k)/(((1-k)*k*R2 + k*R1)/(k*R2 + R1) + ((1-k)**2*R2 + (1-k)*R1)/((1-k)*R2 + R1))
val2 = 1 - (1 - k)/(((1-k)*k*R2 + k*R1)/(k*R2 + R1) + ((1-k)**2*R2 + (1-k)*R1)/((1-k)*R2 + R1))

plot(k, val)
#plot(k, val/val2)

# %% [markdown]
# $$\nabla$$
