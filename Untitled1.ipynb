# %%
import sys
sys.path.append('/Users/aloukian/Documents/pyWinSpec/')
from winspec import *
from itertools import izip
import scipy.signal as sp
from IPython.display import display, Image
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (12,10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from functools import partial

def smooth(signal, N=50):
    window = sp.get_window(('kaiser', 7.), N, fftbins=False)/N
    return sp.convolve(signal, window, mode='same')

# %%
def make_axis(central=500, bw=140, npix=1340):
    return concatenate([linspace(central - bw/2., central, npix/2., endpoint=False), linspace(central, central + bw/2., npix/2., endpoint=True)])

# %%
d = '/Volumes/jogilvie/2D/Data/13-11-21/Stark/'
f1 = SpeFile(d + 'Probe_Stability_04.SPE'); display(f1)
dat = f1.data.squeeze()
#ref_spec = mean(dat, axis=0)
even = dat[2::2, :]
odd = dat[1::2, :]
ref = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-11-21/Stark/Probe_Stability_04.SPE
# 	1340x1 area, 14715 frames
# 	Taken on 21Nov2013

# %%
f1 = SpeFile(d + 'Stark_3KV.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv3 = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-11-21/Stark/Stark_3KV.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 21Nov2013

# %%
f1 = SpeFile(d + 'Stark_3KV_01.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv3_01 = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-11-21/Stark/Stark_3KV_01.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 21Nov2013

# %%
f1 = SpeFile(d + 'Stark_4p6KV.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv4p6_01 = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-11-21/Stark/Stark_4p6KV.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 21Nov2013

# %%
f1 = SpeFile(d + 'Stark_4p6KV_02.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv5p2_long = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-11-21/Stark/Stark_4p6KV_02.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 21Nov2013

# %%
plot(wave, ref_spec)

grid(which='major')

# %%
ticklabel_format(style='sci', axis='y', scilimits=(0,0))
wave = make_axis()
plot(wave, smooth(hv3 - hv3.mean()))
plot(wave, smooth(hv3_01 - hv3_01.mean()))
plot(wave, smooth(hv4p6_01- hv4p6_01.mean()))
#plot(wave, (hv5p2)))
#plot(wave, boxcar(hv5p2_long) - hv5p2_long.mean())
plot(wave, smooth(ref - ref.mean()))
grid()
savefig('preview.png', dpi=300)

# %%
#net = zeros((1340,), dtype=float64)
#plot(mean(log(even) - log(odd), axis=0))
#grid()
A = log10(aeven) - log10(aodd)
#plot(A[50, :])
#plot(A[150, :])
plot(A)
grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-93822ab2c417> in <module>()
#       2 #plot(mean(log(even) - log(odd), axis=0))
#       3 #grid()
# ----> 4 A = log10(aeven) - log10(aodd)
#       5 #plot(A[50, :])
#       6 #plot(A[150, :])
#
# NameError: name 'aeven' is not defined

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-11-04/'
f1 = SpeFile(d + 'tdTomato_Cryostat_RT_01.SPE'); display(f1)
dat = f1.data.squeeze()
room_temp = mean(dat, axis=0)
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-11-04/tdTomato_Cryostat_RT_01.SPE
# 	335x1 area, 20000 frames
# 	Taken on 04Nov2013

# %%
central = 540
bandwidth = 140
npix = 1340/4
dl = concatenate([linspace(central - bandwidth/2., central, npix/2., endpoint=False), linspace(central, central + bandwidth/2., npix/2. + 1, endpoint=True)])

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-11-04/'
f1 = SpeFile(d + 'tdTomato_Cryostat_77K_01.SPE'); display(f1)
dat = f1.data.squeeze()
cryo_ref = mean(dat, axis=0)
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-11-04/tdTomato_Cryostat_77K_01.SPE
# 	335x1 area, 20000 frames
# 	Taken on 04Nov2013

# %%
plot(dl, -log10(room_temp) + log10(ref) + 0.07, label='room temp')
plot(dl, -log10(cryo_ref) + log10(ref) + 0.07, label='77K')
vlines(555, 0, 0.2)
gca().invert_xaxis()
grid()

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-11-04/'
f1 = SpeFile(d + 'tdTomato_Cryostat_77K_LS_5KV.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv5 = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-11-04/tdTomato_Cryostat_77K_LS_5KV.SPE
# 	335x1 area, 20000 frames
# 	Taken on 04Nov2013

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-11-04/'
f1 = SpeFile(d + 'tdTomato_Cryostat_77K_LS_7KV.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
hv7 = mean(log10(even) - log10(odd), axis=0)
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-11-04/tdTomato_Cryostat_77K_LS_7KV.SPE
# 	335x1 area, 20000 frames
# 	Taken on 04Nov2013

# %%
#plot(hv7)
plot(dl, boxcar(hv7)*1e6)
#plot(boxcar(hv5))
grid()
#plot(cryo_ref)

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'LD750_LS_7kv.SPE'); display(f1)
dat = f1.data.squeeze()
s
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
ld750_7kv = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/LD750_LS_7kv.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 30Oct2013
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c9ac5a9f2a3f> in <module>()
#       2 f1 = SpeFile(d + 'LD750_LS_7kv.SPE'); display(f1)
#       3 dat = f1.data.squeeze()
# ----> 4 s
#       5 aeven = mean(even, axis=0)
#       6 aodd = mean(odd, axis=0)
#
# NameError: name 's' is not defined

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'LD750_LS_7_9kv.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
ld750_7_9kv = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/LD750_LS_7_9kv.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 30Oct2013

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'LD750_LS_7_5kv.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
ld750_7_5kv = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/LD750_LS_7_5kv.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 30Oct2013

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'Probe_Stability_Linear_Stark_03.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
stability3 = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/Probe_Stability_Linear_Stark_03.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 30Oct2013

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'Probe_Stability_Linear_Stark_02.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
stability2 = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/Probe_Stability_Linear_Stark_02.SPE
# 	1340x1 area, 10000 frames
# 	Taken on 30Oct2013

# %%
d = '/Users/aloukian/Documents/ogilvielab/Data/13-10-30/'
f1 = SpeFile(d + 'Probe_Stability_Linear_Stark_01.SPE'); display(f1)
dat = f1.data.squeeze()
even = dat[0::2, :]
odd = dat[1::2, :]
aeven = mean(even, axis=0)
aodd = mean(odd, axis=0)
stability1 = boxcar(log10(aeven/aodd))
# Out:
# SPE File /Users/aloukian/Documents/ogilvielab/Data/13-10-30/Probe_Stability_Linear_Stark_01.SPE
# 	1340x1 area, 10000 frames
# 	Taken on 30Oct2013

# %%
plot(ld750_7_5kv, label='7.5')
plot(ld750_7_9kv, label='7.9 (after breakdown?)')
plot(ld750_7kv, label='7')
plot(ld750_5kv, label='5')
legend(bbox_to_anchor=(0.5, 0), loc=8, borderaxespad=0., ncol=2)
ylabel('OD')
xlabel('pixel')
savefig('results.png', dpi=300)

# %%
plot(stability1, label='stability1')
plot(stability2, label='stability2')
plot(stability3, label='stability3')
legend()
ylabel('OD')
xlabel('pixel')
savefig('stability.png', dpi=300)
