# %%
import sys
sys.path.append('/Users/aloukian/Documents/pyWinSpec/')
from winspec import *
from itertools import izip
import scipy.signal as signal
from functools import partial
#from IPython.display import display, Image
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (16, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['hamming']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
hamming = partial(convolve,  signal.get_window('hamming', 50)/50, mode='same')

# %%
d = '/Volumes/jogilvie/2D/Data/13-12-04/Stark/'
f1 = SpeFile(d + 'Pentacene_77K_580nm_1p5KV_01.SPE'); display(f1)
#f2 = SpeFile(d + '02_Pentacene_WO_HV.SPE'); display(f2)

dat1 = asfarray(squeeze(f1.data))
#dat2 = asfarray(squeeze(f2.data))

lam = linspace(580 - 75, 580+75, f1.data.shape[1])
hc = 4.135667516e-15 * 299792458e9 # Planck's constant in eV*s * speed of light in nm/s
ev = hc/lam
#favg1 = mean(dat1, axis=0)
#favg2 = mean(dat2, axis=0)
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-12-04/Stark/Pentacene_77K_580nm_1p5KV_01.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 04Dec2013

# %%
d = '/Volumes/jogilvie/2D/Data/13-12-04/Stark/'
f1 = SpeFile(d + 'Probe_Stability_03.SPE'); display(f1)
#f2 = SpeFile(d + '02_Pentacene_WO_HV.SPE'); display(f2)

dat1 = asfarray(squeeze(f1.data[20:-20, :]))
# Out:
# SPE File /Volumes/jogilvie/2D/Data/13-12-04/Stark/Probe_Stability_03.SPE
# 	1340x1 area, 20000 frames
# 	Taken on 04Dec2013

# %%
ref = dat1.mean(axis=0)
#ref.shape
plot(lam, ref)

# %%
ref_uv_vis = np.genfromtxt('/Volumes/lsa-research04/jogilvie/UV-Vis spectra/pentacene_S1_50um (2013 Nov 27).csv', delimiter=',', skip_header=2)

# %%
plot(ref_uv_vis[:, 0], ref_uv_vis[:, 1])
plot(lam, -(log10(even) - log10(ref)) + 0.4)

# %%
plot(lam, -(log10(even) - log10(ref)))

# %%
# Out:
# array([  5.93648432e+14,   5.93516772e+14,   5.93385171e+14, ...,
#          4.57855022e+14,   4.57776702e+14,   4.57698409e+14])

# %% [markdown]
# speed of light = $2.997924580\cdot10^8\ \text{m/s}$

# %%
from scipy.interpolate import interp1d
import quantities as qt

dat = even
n = even.shape[0]

# Interpolate to have even frequency spacing
lam = linspace(580-75, 580+75, f1.data.shape[1])
c = 299792458.0

f, df = linspace(c*1e9/np.max(lam), c*1e9/np.min(lam), n, endpoint=True, retstep=True)

#windowed = dat[::-1]
padded = np.zeros((n*6,))
padded[:n] = dat[::-1]*kaiser(n, 7.9)
#padded *= kaiser(n*6, 4.9)
#lam_padded = arange(f, df) 
spec_f = interp1d(c*1e9/lam[::-1], windowed)
#plot(spec_f(f))
plot(f, spec_f(f))
xlabel('frequency (Hz)')
title('Glass slide');
#cstd*1e9/lam

# %%
plot(padded)

# %%
plot(fftshift(fft.fftfreq(n*6, df)), abs(fftshift(fft.fft(padded))))
xlim((0, 0.2e-12))
vlines([0.075e-13, 0.20e-13, 0.5e-13], 0, 1e7)
grid()

# %%
(0.5e-13*qt.s*qt.speed_of_light*3).rescale('um')
# Out:
# array(44.96886870000001) * um

# %%
print f
print c/lam[::-1]
#
print spec_f(f)
# Out:
# [  4.57698409e+14   4.57799940e+14   4.57901471e+14 ...,   5.93445370e+14
#    5.93546901e+14   5.93648432e+14]
# [  4.57698409e+14   4.57776702e+14   4.57855022e+14 ...,   5.93385171e+14
#    5.93516772e+14   5.93648432e+14]

# %%
1./np.max(lam.rescale('nm').magnitude)
# Out:
# 0.0015267175572519084

# %%
qt.speed_of_light
# Out:
# UnitQuantity('speed_of_light', 299792458.0 * m/s, 'c')

# %%
spec_f(f[:-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-7eb9200be860> in <module>()
# ----> 1 spec_f(f[:-1])
#
# /usr/local/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      52         """
#      53         x, x_shape = self._prepare_x(x)
# ---> 54         y = self._evaluate(x)
#      55         return self._finish_y(y, x_shape)
#      56
#
# /usr/local/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     446         #    The behavior is set by the bounds_error variable.
#     447         x_new = asarray(x_new)
# --> 448         out_of_bounds = self._check_bounds(x_new)
#     449         y_new = self._call(self, x_new)
#     450         if len(y_new) > 0:
#
# /usr/local/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _check_bounds(self, x_new)
# ...

# %%
f
# Out:
# array([  5.93648432e+14,   5.93546901e+14,   5.93445370e+14, ...,
#          4.57901471e+14,   4.57799940e+14,   4.57698409e+14])

# %%
plot(lam, -(log10(even) - log10(odd)))

# %%
data = dat1[20:]
even = (data[0::2]).mean(axis=0)
#odd = hamming((data[1::2]).mean(axis=0))

# %%
keep = slice(50, -50)
#plot(lam[keep], even[keep])
plot(lam[keep], log10(even[keep]/odd[keep]))

# %%
# Out:
# (1240,)
